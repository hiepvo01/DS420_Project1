# %%
import pandas as pd

# %%
df = pd.read_csv("../kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7      1180.0              0
# 1      7242     2.0           0     0  ...      7      2170.0            400
# 2     10000     1.0           0     0  ...      6       770.0              0
# 3      5000     1.0           0     0  ...      7      1050.0            910
# 4      8080     1.0           0     0  ...      8      1680.0              0
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.yr_built.unique()
# Out:
# array([1955, 1951, 1933, 1965, 1987, 2001, 1995, 1963, 1960, 2003, 1942,
#        1927, 1977, 1900, 1979, 1994, 1916, 1921, 1969, 1947, 1968, 1985,
#        1941, 1915, 1909, 1948, 2005, 1929, 1981, 1930, 1904, 1996, 2000,
#        1984, 2014, 1922, 1959, 1966, 1953, 1950, 2008, 1991, 1954, 1973,
#        1925, 1989, 1972, 1986, 1956, 2002, 1992, 1964, 1952, 1961, 2006,
#        1988, 1962, 1939, 1946, 1967, 1975, 1980, 1910, 1983, 1978, 1905,
#        1971, 2010, 1945, 1924, 1990, 1914, 1926, 2004, 1923, 2007, 1976,
#        1949, 1999, 1901, 1993, 1920, 1997, 1943, 1957, 1940, 1918, 1928,
#        1974, 1911, 1936, 1937, 1982, 1908, 1931, 1998, 1913, 2013, 1907,
#        1958, 2012, 1912, 2011, 1917, 1932, 1944, 1902, 2009, 1903, 1970,
#        2015, 1934, 1938, 1919, 1906, 1935], dtype=int64)

# %%
years = []
for d in df.date:
    years.append(d[0:4])
df["Year"] = years

# %%
df.Year.unique()
# Out:
# array(['2014', '2015'], dtype=object)

# %%
# Function for counting nearby places and nearest distance
import requests
import json
import time

APIKEY = "AIzaSyAYHI79FbhX387OXrYoVBmoPw3X0FPQac4"

# supermarket, restaurant, park

def nearBy(loc=("47.605679","-122.113736"),radius=25000, type = "restaurant"):
    def findPlaces(pagetoken, count, coors):
        lat, lng = loc
        url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&type={type}&key={APIKEY}{pagetoken}".format(lat = lat, lng = lng, radius = radius, type = type,APIKEY = APIKEY, pagetoken = "&pagetoken="+pagetoken if pagetoken else "")
        response = requests.get(url)
        res = json.loads(response.text)

        print("here results ---->>> ", len(res["results"]))
        count += len(res["results"])
        
        for result in res["results"]:
            info = ";".join(map(str,[result["name"],result["geometry"]["location"]["lat"],result["geometry"]["location"]["lng"],result.get("rating",0),result["place_id"]]))
            coors.append((result["geometry"]["location"]["lat"],result["geometry"]["location"]["lng"]))  
            print(info)
        pagetoken = res.get("next_page_token",None)
        return pagetoken, count, coors
    
    pagetoken = None
    count = 0
    coors = []
    while True:
        pagetoken, count, coors = findPlaces(pagetoken, count, coors)
        time.sleep(7)

        if not pagetoken:
            break
    return count, coors

# %%
count, coors = nearBy()
# Out:
# here results ---->>>  20
# Fairmont Olympic Hotel - Seattle;47.6080639;-122.3339273;4.6;ChIJf3uV-rNqkFQRmkmlotz3KN0
# The Woodmark Hotel;47.6568222;-122.2071;4.6;ChIJ2_L9biwTkFQRCMXqMf-4_e0
# Silver Cloud Hotel - University District;47.6658333;-122.2994444;4.3;ChIJdS0Vx4cUkFQRv-UDFEvfpKY
# Kimpton Hotel Vintage Seattle;47.6076086;-122.3325799;4.4;ChIJJ6iYtLZqkFQRGEtPwzzHb48
# Mayflower Park;47.61219790000001;-122.3380528;4.4;ChIJ25ZqU0sVkFQRkt7IsXnTjLs
# Cedarbrook Lodge;47.43704509999999;-122.2876461;4.7;ChIJO0gcqaZckFQRH-GoCnJ01mk
# Buca di Beppo Italian Restaurant;47.6259415;-122.3390615;4;ChIJqcEWDzkVkFQRApc1W87ZbEE
# Japonessa Sushi Cocina;47.6080322;-122.338974;4.5;ChIJUwksT7JqkFQR3kjlZYrA0XY
#  (47.6427083, -122.199109),
#  (47.6568222, -122.2071),
#  (47.6734713, -122.1303788),
#  (47.575401, -122.1297761),
#  (47.6348249, -122.1471007),
#  (47.6101497, -122.2015159),
#  (47.5510145, -122.0600579),
#  (47.5801026, -122.1437375),
#  (47.61474809999999, -122.2074169),
#  (47.66839600000001, -122.105228),
#  (47.5806756, -122.1541412),
#  (47.61563109999999, -122.2040024),
#  (47.672085, -122.1218976),
#  (47.6339321, -122.1471802),
#  (47.6139737, -122.1822893),
#  (47.6600477, -122.1079176),
# ...

# %%
count2, coors2 = nearBy(type = "park")
# Out:
# here results ---->>>  20
# Marymoor Park;47.6600477;-122.1079176;4.7;ChIJ0fWNvq9ykFQRHWk-yNgbKgo
# Gas Works Park;47.6456308;-122.3343532;4.7;ChIJf7BbsgIVkFQRlmFJ7KtVbh4
# Snoqualmie Falls;47.5470096;-121.8404197;4.7;ChIJT6dOHNF7kFQRhSFgNROsXec
# Olympic Sculpture Park;47.6166028;-122.3553167;4.5;ChIJc88dJ1AVkFQRmZ_S-xv-_Hs
# Seward Park;47.5496046;-122.2573574;4.7;ChIJ8fB3DCFqkFQRuPuGyAgceTw
# Seattle Japanese Garden;47.6290005;-122.2962936;4.6;ChIJQ3K1QtIUkFQRNM3jmnMDMVk
# Bellevue Botanical Garden;47.6091944;-122.1787564;4.7;ChIJtyvP_2ZskFQRAz9MdO6RqfM
# Lincoln Park;47.53057099999999;-122.395992;4.7;ChIJnRb12DlBkFQR_SuL0fockuc
# Lake Sammamish State Park;47.5599435;-122.0554823;4.6;ChIJFZddJa9vkFQRqmHy4SfkGPw
# Volunteer Park;47.6310836;-122.3163794;4.7;ChIJ3TTM_CcVkFQRtMStux6Hvyw
# Occidental Square;47.600506;-122.3332236;4.3;ChIJpzPF0rpqkFQRLLkTgGwPj1k
# Discovery Park;47.6580466;-122.4180885;4.8;ChIJn0CO4fAVkFQRIGP6pMpCmFE
# ...

# %%
count2
# Out:
# 60

# %%
coors2
# Out:
# [(47.6600477, -122.1079176),
#  (47.6456308, -122.3343532),
#  (47.5470096, -121.8404197),
#  (47.6166028, -122.3553167),
#  (47.5496046, -122.2573574),
#  (47.6290005, -122.2962936),
#  (47.6091944, -122.1787564),
#  (47.53057099999999, -122.395992),
#  (47.5599435, -122.0554823),
#  (47.6310836, -122.3163794),
#  (47.600506, -122.3332236),
#  (47.6580466, -122.4180885),
#  (47.6294692, -122.3599224),
#  (47.5276489, -122.1096207),
#  (47.6917517, -122.4030912),
#  (47.6109571, -122.3370146),
#  (47.60704, -122.3418276),
#  (47.6126836, -122.2041686),
#  (47.5459311, -122.0019189),
#  (47.5133132, -122.2664458),
#  (47.71159549999999, -122.3682005),
#  (47.66835340000001, -122.1457814),
#  (47.6390278, -121.9022194),
#  (47.5655918, -122.2785452),
#  (47.668731, -122.3037237),
#  (47.619238, -122.2821609),
#  (47.6439141, -121.9247524),
#  (47.7047085, -122.2153623),
#  (47.5784092, -121.9781335),
#  (47.619438, -122.361817),
#  (47.5911806, -122.2256684),
# ...

# %%
import json

places = [
            {'restaurant': {'count': count, 'coors': coors}},
            {'shopping': {'count': count1, 'coors': coors1}},
            {'park': {'count': count2, 'coors': coors2}}
         ]

json = json.dumps(places)
f = open("places.json","w")
f.write(json)
f.close()

# %%
df.to_csv('../house_data_processed.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21611 non-null  float64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...
